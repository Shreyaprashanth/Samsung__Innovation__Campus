# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyaprashanth/Samsung__Innovation__Campus/blob/main/Mushroom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data='/content/drive/MyDrive/0.Samsung CSR AIML/Resources/SIC-Artificial-Intelligence/SIC_AI_Coding_Exercises/SIC_AI_Chapter_05_Coding_Exercises/Clustering_mushroom.csv'

# %%
import pandas as pd
df = pd.read_csv(data,delimiter=',')
df.describe()
# Out:
#          poisonous  cap_shape_eq_convex  cap_shape_eq_bell  \
# count  8124.000000          8124.000000        8124.000000
# mean      0.482029             0.450025           0.055638
# std       0.499708             0.497527           0.229235
# min       0.000000             0.000000           0.000000
# 25%       0.000000             0.000000           0.000000
# 50%       0.000000             0.000000           0.000000
# 75%       1.000000             1.000000           0.000000
# max       1.000000             1.000000           1.000000
#
#        cap_shape_eq_sunken  cap_shape_eq_flat  cap_shape_eq_knobbed  \
# count          8124.000000        8124.000000           8124.000000
# mean              0.003939           0.387986              0.101920
# std               0.062641           0.487321              0.302562
# min               0.000000           0.000000              0.000000
# 25%               0.000000           0.000000              0.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))

print(df.columns)
# Out:
# Index(['poisonous', 'cap_shape_eq_convex', 'cap_shape_eq_bell',
#        'cap_shape_eq_sunken', 'cap_shape_eq_flat', 'cap_shape_eq_knobbed',
#        'cap_shape_eq_conical', 'cap_surface_eq_smooth', 'cap_surface_eq_scaly',
#        'cap_surface_eq_fibrous',
#        ...
#        'population_eq_several', 'population_eq_solitary',
#        'population_eq_clustered', 'habitat_eq_urban', 'habitat_eq_grasses',
#        'habitat_eq_meadows', 'habitat_eq_woods', 'habitat_eq_paths',
#        'habitat_eq_waste', 'habitat_eq_leaves'],
#       dtype='object', length=114)

# %%
plt.figure(figsize=(10,6))
df[df['poisonous']==1]['cap_shape_eq_convex'].hist(alpha=0.5,color='blue',  bins=30,label='Poisonous=1')
df[df['poisonous']==0]['cap_shape_eq_convex'].hist(alpha=0.5,color='red', bins=30,label='Poisonous=0')
plt.legend()
plt.xlabel('Feature Value')
# Out:
# Text(0.5, 0, 'Feature Value')

# %%
plt.figure(figsize=(10,6))
df[df['population_eq_several']==1]['cap_shape_eq_bell'].hist(alpha=0.5,color='blue', bins=30,label='population_eq_several=1')
df[df['population_eq_several']==0]['cap_shape_eq_bell'].hist(alpha=0.5,color='red', bins=30,label='population_eq_several=0')
plt.legend()
plt.xlabel('cap_shape_eq_bell')
# Out:
# Text(0.5, 0, 'cap_shape_eq_bell')

# %%
import seaborn as sns
plt.figure(figsize=(11,7))
sns.countplot(x='poisonous',hue='population_eq_several',data=df,palette='Set1')
# Out:
# <Axes: xlabel='poisonous', ylabel='count'>

# %%
cat_feats = ['poisonous']

# %%
final_data = pd.get_dummies(df,columns=cat_feats,drop_first=True)
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Columns: 114 entries, cap_shape_eq_convex to poisonous_1
# dtypes: bool(1), int64(113)
# memory usage: 7.0 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('cap_shape_eq_bell',axis=1)
y = final_data['cap_shape_eq_bell']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2310
#            1       0.99      0.99      0.99       128
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2309    1]
#  [   1  127]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %%
predictions = rfc.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2310
#            1       1.00      0.87      0.93       128
#
#     accuracy                           0.99      2438
#    macro avg       1.00      0.93      0.96      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2310    0]
#  [  17  111]]
